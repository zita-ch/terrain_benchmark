# %%
from model import *
import numpy as np
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
# from dataset_builder import *


def generate_real_samples(dataset, ground_trud_ds, n_samples, patch_size):
    ix = np.random.randint(0, dataset.shape[0], n_samples)
    X = dataset[ix]
    gt = ground_trud_ds[ix]
    y = np.ones((n_samples, patch_size, patch_size, 1))
    return X, y, gt


def generate_fake_samples(g_model, dataset, patch_size):
    w_noise = np.random.normal(0, 1, (dataset.shape[0], 14, 14, 1024))
    X = g_model.predict([dataset, w_noise])
    y = np.zeros((len(X), patch_size, patch_size, 1))
    return X, y


def sample_images(generator, source, target, idx):
    print(target.shape)
    target = np.uint8(target * 127.5 + 127.5)
    w_noise = np.random.normal(0, 1, (1, 14, 14, 1024))
    predicted = generator.predict([source, w_noise])
    im = np.uint8(predicted[0, ...] * 127.5 + 127.5)
    im_source = np.uint8(source[0, ...] * 255)
    print(im_source.shape)
    im_c = np.concatenate((np.squeeze(im, axis=-1), np.squeeze(target, axis=-1),
                           im_source[..., 0], im_source[..., 1]), axis=1)
    plt.imsave('./outputs/sketch_conversion' + str(idx) + '.png', im_c, cmap='terrain')



def train_gan():
    data = np.load('training_data4.npz')
    XTrain = data['x']
    YTrain = data['y']
    input_shape_gen = (XTrain.shape[1], XTrain.shape[2], XTrain.shape[3])
    input_shape_disc = (YTrain.shape[1], YTrain.shape[2], YTrain.shape[3])
    print(input_shape_gen,input_shape_disc)

    terrain_generator = UNet(input_shape_gen)
    terrain_discriminator = patch_discriminator(input_shape_disc)
    optd = Adam(0.0001, 0.5)
    terrain_discriminator.compile(loss='binary_crossentropy', optimizer=optd)
    composite_model = mount_discriminator_generator(
        terrain_generator, terrain_discriminator, input_shape_gen)
    composite_model.compile(
        loss=[
            'binary_crossentropy', 'mae'], loss_weights=[
            1, 3], optimizer=optd)

    n_epochs, n_batch, = 150, 20
    bat_per_epo = int(len(XTrain) / n_batch)
    patch_size = 15
    n_steps = bat_per_epo * n_epochs
    min_loss = 999
    avg_loss = 0
    avg_dloss = 0
    for i in range(n_steps):
        X_real, labels_real, Y_target = generate_real_samples(XTrain, YTrain, n_batch, patch_size)
        Y_target[np.isnan(Y_target)] = 0
        X_real[np.isnan(X_real)] = 0
        
        # mask 
        mask = np.random.uniform(low=0.0, high=1.0, size=X_real.shape)>0.75 # mask 75 %
        X_real = X_real* mask

        Y_fake, labels_fake = generate_fake_samples(terrain_generator, X_real, patch_size)
        w_noise = np.random.normal(0, 1, (n_batch, 14, 14, 1024))
        losses_composite = composite_model.train_on_batch(
            [X_real, w_noise], [labels_real, Y_target])

        loss_discriminator_fake = terrain_discriminator.train_on_batch(
            [Y_fake, X_real], labels_fake)
        loss_discriminator_real = terrain_discriminator.train_on_batch(
            [Y_target, X_real], labels_real)
        d_loss = (loss_discriminator_fake + loss_discriminator_real) / 2
        avg_dloss = avg_dloss + (d_loss - avg_dloss) / (i + 1)
        avg_loss = avg_loss + (losses_composite[0] - avg_loss) / (i + 1)

        if i % 100 == 0:
            print(i,'total loss:' + str(avg_loss) + ' d_loss:' + str(avg_dloss))
            sample_images(terrain_generator, X_real[0:1, ...], Y_target[0, ...], i)
        if i % 500 == 0:
            terrain_discriminator.save('terrain_discriminator' + str(i) + '.h5', True)
            terrain_generator.save('terrain_generator' + str(i) + '.h5', True)

import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

train_gan()
# Out:
# Num GPUs Available:  4
# (225, 225, 2) (225, 225, 1)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 225, 225, 2) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 225, 225, 64) 1216        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 225, 225, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 14, 14, 1024 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 2048) 0           conv2d_9[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 28, 28, 2048) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 512)  4194816     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 56, 56, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 112, 112, 256 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 112, 112, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 224, 224, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 225, 225, 64) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 225, 225, 128 0           conv2d_1[0][0]
#                                                                  zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 225, 225, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 225, 225, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 225, 225, 32) 18464       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 225, 225, 1)  33          conv2d_22[0][0]
# ==================================================================================================
# Total params: 33,146,753
# Trainable params: 33,146,753
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 225, 225, 2) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 14, 14, 1024 0
# __________________________________________________________________________________________________
# model (Functional)              (None, 225, 225, 1)  33146753    input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 15, 15, 1)    6959553     model[0][0]
#                                                                  input_5[0][0]
# ==================================================================================================
# Total params: 40,106,306
# Trainable params: 33,146,753
# Non-trainable params: 6,959,553
# __________________________________________________________________________________________________
# 0 total loss:2.1351747512817383 d_loss:0.7207650244235992
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 100 total loss:2.4661205652916784 d_loss:0.6850746268830677
# (225, 225, 1)
# (225, 225, 2)
# 200 total loss:2.5924362489833173 d_loss:0.6488100202633673
# (225, 225, 1)
# (225, 225, 2)
# 300 total loss:2.51589955285538 d_loss:0.6595132480254806
# (225, 225, 1)
# (225, 225, 2)
# 400 total loss:2.5013800999172893 d_loss:0.6535405568555558
# (225, 225, 1)
# (225, 225, 2)
# 500 total loss:2.455791227831812 d_loss:0.6550710295473864
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 600 total loss:2.4407718205412317 d_loss:0.6588368582137906
# (225, 225, 1)
# (225, 225, 2)
# 700 total loss:2.4280068687297507 d_loss:0.6506595860970088
# (225, 225, 1)
# (225, 225, 2)
# 800 total loss:2.4329782456494446 d_loss:0.6541736921465274
# (225, 225, 1)
# (225, 225, 2)
# 900 total loss:2.4421808679942694 d_loss:0.6526411654392498
# (225, 225, 1)
# (225, 225, 2)
# 1000 total loss:2.432399706764299 d_loss:0.6505616202049853
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1100 total loss:2.433022020731483 d_loss:0.6475044992413164
# (225, 225, 1)
# (225, 225, 2)
# 1200 total loss:2.4419954545690437 d_loss:0.6456317998543307
# (225, 225, 1)
# (225, 225, 2)
# 1300 total loss:2.4289038729246153 d_loss:0.645740762539064
# (225, 225, 1)
# (225, 225, 2)
# 1400 total loss:2.4186450297452984 d_loss:0.6459334936447638
# (225, 225, 1)
# (225, 225, 2)
# 1500 total loss:2.4077242648577717 d_loss:0.646733708706976
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1600 total loss:2.400429072043512 d_loss:0.646902671501477
# (225, 225, 1)
# (225, 225, 2)
# 1700 total loss:2.3936879583697426 d_loss:0.6471891280927241
# (225, 225, 1)
# (225, 225, 2)
# 1800 total loss:2.389517893796496 d_loss:0.6463096922554112
# (225, 225, 1)
# (225, 225, 2)
# 1900 total loss:2.387583270316251 d_loss:0.6464796486217078
# (225, 225, 1)
# (225, 225, 2)
# 2000 total loss:2.3820758515271745 d_loss:0.6460316867131486
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2100 total loss:2.377772377934248 d_loss:0.646154749826454
# (225, 225, 1)
# (225, 225, 2)
# 2200 total loss:2.3717845382066503 d_loss:0.6468503223626322
# (225, 225, 1)
# (225, 225, 2)
# 2300 total loss:2.3639284761922874 d_loss:0.6475879376440882
# (225, 225, 1)
# (225, 225, 2)
# 2400 total loss:2.3552969184730115 d_loss:0.647854875521838
# (225, 225, 1)
# (225, 225, 2)
# 2500 total loss:2.345949208483796 d_loss:0.6487147053886128
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2600 total loss:2.3369402939977193 d_loss:0.649513297025021
# (225, 225, 1)
# (225, 225, 2)
# 2700 total loss:2.330136382151692 d_loss:0.6500566725483624
# (225, 225, 1)
# (225, 225, 2)
# 2800 total loss:2.321607749022062 d_loss:0.650852541870482
# (225, 225, 1)
# (225, 225, 2)
# 2900 total loss:2.3140574731484893 d_loss:0.6514826326090702
# (225, 225, 1)
# (225, 225, 2)
# 3000 total loss:2.306694204789007 d_loss:0.6519573910974311
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 3100 total loss:2.300281753197134 d_loss:0.6523258020330708
# (225, 225, 1)
# (225, 225, 2)
# 3200 total loss:2.294590654875181 d_loss:0.6526579264631697
# (225, 225, 1)
# (225, 225, 2)
# 3300 total loss:2.2887823565805796 d_loss:0.6531067621566614
# (225, 225, 1)
# (225, 225, 2)
# 3400 total loss:2.2828065377409015 d_loss:0.6534412492803786
# (225, 225, 1)
# (225, 225, 2)
# 3500 total loss:2.2774363244407287 d_loss:0.6539366486929488
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 3600 total loss:2.2722167981660744 d_loss:0.6543621122412905
# (225, 225, 1)
# (225, 225, 2)
# 3700 total loss:2.266922275397108 d_loss:0.6547208334561107
# (225, 225, 1)
# (225, 225, 2)
# 3800 total loss:2.262195788725711 d_loss:0.6552187109832083
# (225, 225, 1)
# (225, 225, 2)
# 3900 total loss:2.2573983408310117 d_loss:0.6555833295761195
# (225, 225, 1)
# (225, 225, 2)
# 4000 total loss:2.2526578281379206 d_loss:0.655966077079977
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 4100 total loss:2.248222858520344 d_loss:0.6564586265605357
# (225, 225, 1)
# (225, 225, 2)
# 4200 total loss:2.243879078626915 d_loss:0.656794873014594
# (225, 225, 1)
# (225, 225, 2)
# 4300 total loss:2.2400503881419445 d_loss:0.6569109193814415
# (225, 225, 1)
# (225, 225, 2)
# 4400 total loss:2.2365020591815608 d_loss:0.6572468751418056
# (225, 225, 1)
# (225, 225, 2)
# 4500 total loss:2.2330174635474243 d_loss:0.657590323058078
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 4600 total loss:2.229546048956787 d_loss:0.6577886120140755
# (225, 225, 1)
# (225, 225, 2)
# 4700 total loss:2.2268039243471383 d_loss:0.6581579516995446
# (225, 225, 1)
# (225, 225, 2)
# 4800 total loss:2.2232718770887914 d_loss:0.6582976595735894
# (225, 225, 1)
# (225, 225, 2)
# 4900 total loss:2.2206812070793274 d_loss:0.6585243294679515
# (225, 225, 1)
# (225, 225, 2)
# 5000 total loss:2.2183272978516295 d_loss:0.6585556323122556
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5100 total loss:2.2159801472450975 d_loss:0.6585515911397521
# (225, 225, 1)
# (225, 225, 2)
# 5200 total loss:2.213422022423272 d_loss:0.6587120250556513
# (225, 225, 1)
# (225, 225, 2)
# 5300 total loss:2.21133285588846 d_loss:0.6588915955437659
# (225, 225, 1)
# (225, 225, 2)
# 5400 total loss:2.208687899311789 d_loss:0.6590692466643949
# (225, 225, 1)
# (225, 225, 2)
# 5500 total loss:2.2061607886435572 d_loss:0.6592105777175413
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5600 total loss:2.203948049242208 d_loss:0.6594175613360423
# (225, 225, 1)
# (225, 225, 2)
# 5700 total loss:2.201504652572502 d_loss:0.6594818963289772
# (225, 225, 1)
# (225, 225, 2)
# 5800 total loss:2.19904771621341 d_loss:0.6596345712039552
# (225, 225, 1)
# (225, 225, 2)
# 5900 total loss:2.196391470006834 d_loss:0.659747298332172
# (225, 225, 1)
# (225, 225, 2)
# 6000 total loss:2.1942674857817988 d_loss:0.6599026879594015
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 6100 total loss:2.192352281439753 d_loss:0.6599513258943177
# (225, 225, 1)
# (225, 225, 2)
# 6200 total loss:2.190374735400975 d_loss:0.6600229399195574
# (225, 225, 1)
# (225, 225, 2)
# 6300 total loss:2.188596879787017 d_loss:0.6600806406064903
# (225, 225, 1)
# (225, 225, 2)
# 6400 total loss:2.186582276884828 d_loss:0.6602222396392863
# (225, 225, 1)
# (225, 225, 2)
# 6500 total loss:2.1847876110841193 d_loss:0.6603460226272742
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 6600 total loss:2.1830062079187638 d_loss:0.6605158269878306
# (225, 225, 1)
# (225, 225, 2)
# 6700 total loss:2.181508651635056 d_loss:0.6605586983928402
# (225, 225, 1)
# (225, 225, 2)
# 6800 total loss:2.179604882072865 d_loss:0.6606401729084859
# (225, 225, 1)
# (225, 225, 2)
# 6900 total loss:2.1777217248231997 d_loss:0.6608169585214845
# (225, 225, 1)
# (225, 225, 2)
# 7000 total loss:2.175935820245245 d_loss:0.660916654718463
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7100 total loss:2.1738276238039234 d_loss:0.6610693807891153
# (225, 225, 1)
# (225, 225, 2)
# 7200 total loss:2.171981844036566 d_loss:0.6612017705251277
# (225, 225, 1)
# (225, 225, 2)
# 7300 total loss:2.170083384908334 d_loss:0.6613639836444385
# (225, 225, 1)
# (225, 225, 2)
# 7400 total loss:2.168470307357116 d_loss:0.6614829246823043
# (225, 225, 1)
# (225, 225, 2)
# 7500 total loss:2.166494461540028 d_loss:0.6615945112142448
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7600 total loss:2.1645815942086992 d_loss:0.6617606188403545
# (225, 225, 1)
# (225, 225, 2)
# 7700 total loss:2.1628116109188213 d_loss:0.6619343680961274
# (225, 225, 1)
# (225, 225, 2)
# 7800 total loss:2.1609552962063914 d_loss:0.6620522899594502
# (225, 225, 1)
# (225, 225, 2)
# 7900 total loss:2.159051121209122 d_loss:0.6621827890846831
# (225, 225, 1)
# (225, 225, 2)
# 8000 total loss:2.1574096910030653 d_loss:0.6623046817089231
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 8100 total loss:2.1559298783228025 d_loss:0.6624381846184173
# (225, 225, 1)
# (225, 225, 2)
# 8200 total loss:2.1546719473406335 d_loss:0.66257560403545
# (225, 225, 1)
# (225, 225, 2)
# 8300 total loss:2.1532303440098333 d_loss:0.6626501140238454
# (225, 225, 1)
# (225, 225, 2)
# 8400 total loss:2.1519728132180242 d_loss:0.662752638796341
# (225, 225, 1)
# (225, 225, 2)
# 8500 total loss:2.150533522511772 d_loss:0.6628486521256369
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 8600 total loss:2.149235605472825 d_loss:0.6629724138995777
# (225, 225, 1)
# (225, 225, 2)
# 8700 total loss:2.1478190955150076 d_loss:0.6630999993268746
# (225, 225, 1)
# (225, 225, 2)
# 8800 total loss:2.1466214643826644 d_loss:0.6631673941054982
# (225, 225, 1)
# (225, 225, 2)
# 8900 total loss:2.1455216930094956 d_loss:0.663266649794301
# (225, 225, 1)
# (225, 225, 2)
# 9000 total loss:2.144009206682002 d_loss:0.663373967861733
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 9100 total loss:2.1428126152656 d_loss:0.6634941153578688
# (225, 225, 1)
# (225, 225, 2)
# 9200 total loss:2.141498690039657 d_loss:0.6635703907350569
# (225, 225, 1)
# (225, 225, 2)
# 9300 total loss:2.140354510725553 d_loss:0.6637279043035621
# (225, 225, 1)
# (225, 225, 2)
# 9400 total loss:2.139291207709982 d_loss:0.6637411328061762
# (225, 225, 1)
# (225, 225, 2)
# 9500 total loss:2.1382133370888226 d_loss:0.6638831333860615
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 9600 total loss:2.1370243778229785 d_loss:0.6639137163035825
# (225, 225, 1)
# (225, 225, 2)
# 9700 total loss:2.135988473732464 d_loss:0.6640110630636147
# (225, 225, 1)
# (225, 225, 2)
# 9800 total loss:2.134928585485394 d_loss:0.6640828497907038
# (225, 225, 1)
# (225, 225, 2)
# 9900 total loss:2.13377105555213 d_loss:0.6641624229018124
# (225, 225, 1)
# (225, 225, 2)
# 10000 total loss:2.132676973556018 d_loss:0.6642030692984253
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 10100 total loss:2.131641093356431 d_loss:0.6643293751600108
# (225, 225, 1)
# (225, 225, 2)
# 10200 total loss:2.1306157607025322 d_loss:0.664414837783697
# (225, 225, 1)
# (225, 225, 2)
# 10300 total loss:2.1297208593141876 d_loss:0.6644609187027287
# (225, 225, 1)
# (225, 225, 2)
# 10400 total loss:2.128747408143168 d_loss:0.6644498986791926
# (225, 225, 1)
# (225, 225, 2)
# 10500 total loss:2.127877070147496 d_loss:0.6645481025073072
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 10600 total loss:2.1272180702492682 d_loss:0.6645661186068129
# (225, 225, 1)
# (225, 225, 2)
# 10700 total loss:2.1263274504039775 d_loss:0.6646374010674798
# (225, 225, 1)
# (225, 225, 2)
# 10800 total loss:2.1252662153908886 d_loss:0.6647323413185815
# (225, 225, 1)
# (225, 225, 2)
# 10900 total loss:2.124584049732793 d_loss:0.6647611405499197
# (225, 225, 1)
# (225, 225, 2)
# 11000 total loss:2.123775083003786 d_loss:0.664832534873468
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 11100 total loss:2.122952234217759 d_loss:0.6648694061550968
# (225, 225, 1)
# (225, 225, 2)
# 11200 total loss:2.122404398135697 d_loss:0.6649255321422929
# (225, 225, 1)
# (225, 225, 2)
# 11300 total loss:2.121641497676978 d_loss:0.6649613885230254
# (225, 225, 1)
# (225, 225, 2)
# 11400 total loss:2.1208876902759517 d_loss:0.6650058506750218
# (225, 225, 1)
# (225, 225, 2)
# 11500 total loss:2.120260105414159 d_loss:0.6650388634944824
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 11600 total loss:2.1194201879137182 d_loss:0.665090991354792
# (225, 225, 1)
# (225, 225, 2)
# 11700 total loss:2.118805071205456 d_loss:0.6651033413844092
# (225, 225, 1)
# (225, 225, 2)
# 11800 total loss:2.1180135001773386 d_loss:0.6651629162883667
# (225, 225, 1)
# (225, 225, 2)
# 11900 total loss:2.117339736893843 d_loss:0.6651917082182389
# (225, 225, 1)
# (225, 225, 2)
# 12000 total loss:2.116458563087047 d_loss:0.6652438702488149
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 12100 total loss:2.11570173108413 d_loss:0.6652959580569019
# (225, 225, 1)
# (225, 225, 2)
# 12200 total loss:2.1150354190826723 d_loss:0.6653108997912445
# (225, 225, 1)
# (225, 225, 2)
# 12300 total loss:2.114441699171904 d_loss:0.6653174094349461
# (225, 225, 1)
# (225, 225, 2)
# 12400 total loss:2.1138079640711673 d_loss:0.6653368240911038
# (225, 225, 1)
# (225, 225, 2)
# 12500 total loss:2.113253177409073 d_loss:0.6653477084349085
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 12600 total loss:2.1125839568633733 d_loss:0.6653828232952476
# (225, 225, 1)
# (225, 225, 2)
# 12700 total loss:2.1120128812362653 d_loss:0.6654047998487175
# (225, 225, 1)
# (225, 225, 2)
# 12800 total loss:2.111287827007882 d_loss:0.665437234132441
# (225, 225, 1)
# (225, 225, 2)
# 12900 total loss:2.1107793991976513 d_loss:0.6654754111192618
# (225, 225, 1)
# (225, 225, 2)
# 13000 total loss:2.1101824189596776 d_loss:0.665480103179827
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 13100 total loss:2.1095192888730985 d_loss:0.6655018467050351
# (225, 225, 1)
# (225, 225, 2)
# 13200 total loss:2.109004103399641 d_loss:0.6655299945930372
# (225, 225, 1)
# (225, 225, 2)
# 13300 total loss:2.10841782902714 d_loss:0.6655722585685374
# (225, 225, 1)
# (225, 225, 2)
# 13400 total loss:2.107774401963555 d_loss:0.6655706597662939
# (225, 225, 1)
# (225, 225, 2)
# 13500 total loss:2.1074450834884755 d_loss:0.6655656489400222
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 13600 total loss:2.1068463157568003 d_loss:0.6655959302953788
# (225, 225, 1)
# (225, 225, 2)
# 13700 total loss:2.1063289830531735 d_loss:0.6656149636531827
# (225, 225, 1)
# (225, 225, 2)
# 13800 total loss:2.105871049928185 d_loss:0.6656098451758797
# (225, 225, 1)
# (225, 225, 2)
# 13900 total loss:2.105382267275049 d_loss:0.66565575249481
# (225, 225, 1)
# (225, 225, 2)
# 14000 total loss:2.1049894759607573 d_loss:0.6656933725590655
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14100 total loss:2.1045490922881296 d_loss:0.6657032301178822
# (225, 225, 1)
# (225, 225, 2)
# 14200 total loss:2.1042376898534054 d_loss:0.6656991554961037
# (225, 225, 1)
# (225, 225, 2)
# 14300 total loss:2.103854368169971 d_loss:0.6657099802169202
# (225, 225, 1)
# (225, 225, 2)
# 14400 total loss:2.1034120445193296 d_loss:0.6657283722215636
# (225, 225, 1)
# (225, 225, 2)
# 14500 total loss:2.1030694652808957 d_loss:0.6657036562650569
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14600 total loss:2.1026522730664197 d_loss:0.6657003491326525
# (225, 225, 1)
# (225, 225, 2)
# 14700 total loss:2.102201404794373 d_loss:0.6656727776041351
# (225, 225, 1)
# (225, 225, 2)
# 14800 total loss:2.1016272792187376 d_loss:0.6657112857383384
# (225, 225, 1)
# (225, 225, 2)
# 14900 total loss:2.1011293456983453 d_loss:0.6657319786873965
# (225, 225, 1)
# (225, 225, 2)
# 15000 total loss:2.100587362798409 d_loss:0.6657733940875458
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 15100 total loss:2.10016352559122 d_loss:0.6657539539199
# (225, 225, 1)
# (225, 225, 2)
# 15200 total loss:2.099708287890487 d_loss:0.6657895388759414
# (225, 225, 1)
# (225, 225, 2)
# 15300 total loss:2.09913952632182 d_loss:0.6658105614745644
# (225, 225, 1)
# (225, 225, 2)
# 15400 total loss:2.0986947627913195 d_loss:0.6658322746521312
# (225, 225, 1)
# (225, 225, 2)
# 15500 total loss:2.098202738967397 d_loss:0.6658266510084568
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 15600 total loss:2.097712664021635 d_loss:0.6658522649602803
# (225, 225, 1)
# (225, 225, 2)
# 15700 total loss:2.0971760760826026 d_loss:0.6658635903255434
# (225, 225, 1)
# (225, 225, 2)
# 15800 total loss:2.0968912982931656 d_loss:0.6658527174698493
# (225, 225, 1)
# (225, 225, 2)
# 15900 total loss:2.0965346843069863 d_loss:0.6658669996475539
# (225, 225, 1)
# (225, 225, 2)
# 16000 total loss:2.0961993061209574 d_loss:0.6658695770035171
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 16100 total loss:2.095670393605937 d_loss:0.6659059621107701
# (225, 225, 1)
# (225, 225, 2)
# 16200 total loss:2.0953921661738413 d_loss:0.6658878463100435
# (225, 225, 1)
# (225, 225, 2)
# 16300 total loss:2.094964132434161 d_loss:0.6659161586609932
# (225, 225, 1)
# (225, 225, 2)
# 16400 total loss:2.0946642189562024 d_loss:0.6659110743888832
# (225, 225, 1)
# (225, 225, 2)
# 16500 total loss:2.094358683347661 d_loss:0.6659346799560383
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 16600 total loss:2.093973564768434 d_loss:0.6659596964098008
# (225, 225, 1)
# (225, 225, 2)
# 16700 total loss:2.093592706051256 d_loss:0.6659648835792409
# (225, 225, 1)
# (225, 225, 2)
# 16800 total loss:2.093354037003707 d_loss:0.6659537447452039
# (225, 225, 1)
# (225, 225, 2)
# 16900 total loss:2.0931156168787566 d_loss:0.6659748557163502
# (225, 225, 1)
# (225, 225, 2)
# 17000 total loss:2.0927152983140047 d_loss:0.6660002350382535
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 17100 total loss:2.092157760319478 d_loss:0.6660148491843878
# (225, 225, 1)
# (225, 225, 2)
# 17200 total loss:2.091842955388649 d_loss:0.6660183656058261
# (225, 225, 1)
# (225, 225, 2)
# 17300 total loss:2.0913982084118437 d_loss:0.6660501775153891
# (225, 225, 1)
# (225, 225, 2)
# 17400 total loss:2.0910646269824458 d_loss:0.6660543994003024
# (225, 225, 1)
# (225, 225, 2)
# 17500 total loss:2.090787715008927 d_loss:0.6660718291009812
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 17600 total loss:2.090384582051989 d_loss:0.6660789275267504
# (225, 225, 1)
# (225, 225, 2)
# 17700 total loss:2.0899649885547884 d_loss:0.6661193172668004
# (225, 225, 1)
# (225, 225, 2)
# 17800 total loss:2.0894963219021028 d_loss:0.6661129265520962
# (225, 225, 1)
# (225, 225, 2)
# 17900 total loss:2.089047740440878 d_loss:0.6661452697487508
# (225, 225, 1)
# (225, 225, 2)
# 18000 total loss:2.088608664119586 d_loss:0.6661620093733582
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 18100 total loss:2.088116613740219 d_loss:0.6661932255576161
# (225, 225, 1)
# (225, 225, 2)
# 18200 total loss:2.0878276079868576 d_loss:0.6662228944260148
# (225, 225, 1)
# (225, 225, 2)
# 18300 total loss:2.0874116424133042 d_loss:0.6662201795912878
# (225, 225, 1)
# (225, 225, 2)
# 18400 total loss:2.086943853504602 d_loss:0.6662582998901895
# (225, 225, 1)
# (225, 225, 2)
# 18500 total loss:2.086548406989773 d_loss:0.666260266033516
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 18600 total loss:2.086200821778447 d_loss:0.6662801189879748
# (225, 225, 1)
# (225, 225, 2)
# 18700 total loss:2.085771575636243 d_loss:0.666294847147885
# (225, 225, 1)
# (225, 225, 2)
# 18800 total loss:2.0854963678722997 d_loss:0.6663021884777784
# (225, 225, 1)
# (225, 225, 2)
# 18900 total loss:2.0853259793211407 d_loss:0.6663088967147494
# (225, 225, 1)
# (225, 225, 2)
# 19000 total loss:2.0849571034102903 d_loss:0.6663202576944696
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 19100 total loss:2.0846313838902377 d_loss:0.6663297965335118
# (225, 225, 1)
# (225, 225, 2)
# 19200 total loss:2.0842782603186385 d_loss:0.6663539036683551
# (225, 225, 1)
# (225, 225, 2)
# 19300 total loss:2.084086785192453 d_loss:0.6663394431481751
# (225, 225, 1)
# (225, 225, 2)
# 19400 total loss:2.0836666432319717 d_loss:0.6663728455078445
# (225, 225, 1)
# (225, 225, 2)
# 19500 total loss:2.0833668435184176 d_loss:0.6663694804096223
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 19600 total loss:2.08302327431159 d_loss:0.6663833114153095
# (225, 225, 1)
# (225, 225, 2)
# 19700 total loss:2.082718785974161 d_loss:0.666393803878182
# (225, 225, 1)
# (225, 225, 2)
# 19800 total loss:2.0823207574145735 d_loss:0.666405017056171
# (225, 225, 1)
# (225, 225, 2)
# 19900 total loss:2.082021647227795 d_loss:0.6664145302657779
# (225, 225, 1)
# (225, 225, 2)
# 20000 total loss:2.081791495568791 d_loss:0.6664090691187738
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 20100 total loss:2.081465518632925 d_loss:0.6664099198002126
# (225, 225, 1)
# (225, 225, 2)
# 20200 total loss:2.081221963366592 d_loss:0.6664406262186252
# (225, 225, 1)
# (225, 225, 2)
# 20300 total loss:2.081005414409192 d_loss:0.6664241698162437
# (225, 225, 1)
# (225, 225, 2)
# 20400 total loss:2.0806932410190635 d_loss:0.6664453078515892
# (225, 225, 1)
# (225, 225, 2)
# 20500 total loss:2.080360554781231 d_loss:0.6664377468923504
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 20600 total loss:2.0800630282756165 d_loss:0.6664656966229965
# (225, 225, 1)
# (225, 225, 2)
# 20700 total loss:2.0797945988430975 d_loss:0.6664635347002987
# (225, 225, 1)
# (225, 225, 2)
# 20800 total loss:2.0795125966060324 d_loss:0.6664800293371868
# (225, 225, 1)
# (225, 225, 2)
# 20900 total loss:2.079218611763532 d_loss:0.6664889527060713
# (225, 225, 1)
# (225, 225, 2)
# 21000 total loss:2.078942275247106 d_loss:0.666508513463801
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 21100 total loss:2.0785682928584146 d_loss:0.6665046497797089
# (225, 225, 1)
# (225, 225, 2)
# 21200 total loss:2.078315832593415 d_loss:0.666516008867383
# (225, 225, 1)
# (225, 225, 2)
# 21300 total loss:2.07801378606591 d_loss:0.6665262240409537
# (225, 225, 1)
# (225, 225, 2)
# 21400 total loss:2.077766220991054 d_loss:0.6665366997500322
# (225, 225, 1)
# (225, 225, 2)
# 21500 total loss:2.07755083605542 d_loss:0.6665230605188747
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 21600 total loss:2.0774123814364103 d_loss:0.6665234184908876
# (225, 225, 1)
# (225, 225, 2)
# 21700 total loss:2.077259033678044 d_loss:0.6665068157034453
# (225, 225, 1)
# (225, 225, 2)
# 21800 total loss:2.077064778984018 d_loss:0.6665043076721211
# (225, 225, 1)
# (225, 225, 2)
# 21900 total loss:2.0768042684858687 d_loss:0.6665113476907905
# (225, 225, 1)
# (225, 225, 2)
# 22000 total loss:2.076505870072654 d_loss:0.6665184206073368
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 22100 total loss:2.0762793908404564 d_loss:0.6665222435455805
# (225, 225, 1)
# (225, 225, 2)
# 22200 total loss:2.0760965604383808 d_loss:0.6665243410039895
# (225, 225, 1)
# (225, 225, 2)
# 22300 total loss:2.0759004041980784 d_loss:0.666533097468262
# (225, 225, 1)
# (225, 225, 2)
# 22400 total loss:2.075578806427008 d_loss:0.6665367471591984
# (225, 225, 1)
# (225, 225, 2)
# 22500 total loss:2.075233505797972 d_loss:0.666551420883407
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 22600 total loss:2.074928370388586 d_loss:0.666561620444866
# (225, 225, 1)
# (225, 225, 2)
# 22700 total loss:2.0745864270999057 d_loss:0.6665773057602835
# (225, 225, 1)
# (225, 225, 2)
# 22800 total loss:2.0744082135519646 d_loss:0.6665670203386445
# (225, 225, 1)
# (225, 225, 2)
# 22900 total loss:2.0742555010251547 d_loss:0.6665657940100506
# (225, 225, 1)
# (225, 225, 2)
# 23000 total loss:2.073997571060879 d_loss:0.6665810143527258
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 23100 total loss:2.073716216761071 d_loss:0.666580635362472
# (225, 225, 1)
# (225, 225, 2)
# 23200 total loss:2.073455535359974 d_loss:0.6666010745132435
# (225, 225, 1)
# (225, 225, 2)
# 23300 total loss:2.0731639932303954 d_loss:0.6665955159911849
# (225, 225, 1)
# (225, 225, 2)
# 23400 total loss:2.0729303882293224 d_loss:0.6665928855955183
# (225, 225, 1)
# (225, 225, 2)
# 23500 total loss:2.0727204626293565 d_loss:0.6665899290061169
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 23600 total loss:2.0725233039786737 d_loss:0.6665934412826432
# (225, 225, 1)
# (225, 225, 2)
# 23700 total loss:2.072511495600699 d_loss:0.6665714896657735
# (225, 225, 1)
# (225, 225, 2)
# 23800 total loss:2.072359810365917 d_loss:0.6665614559718409
# (225, 225, 1)
# (225, 225, 2)
# 23900 total loss:2.0721347997998527 d_loss:0.6665707690213715
# (225, 225, 1)
# (225, 225, 2)
# 24000 total loss:2.07195326864338 d_loss:0.6665643916779802
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 24100 total loss:2.071742446564718 d_loss:0.6665627639854351
# (225, 225, 1)
# (225, 225, 2)
# 24200 total loss:2.071598091059864 d_loss:0.6665627223121954
# (225, 225, 1)
# (225, 225, 2)
# 24300 total loss:2.071408550374598 d_loss:0.6665530128870639
# (225, 225, 1)
# (225, 225, 2)
# 24400 total loss:2.0711347641238707 d_loss:0.6665644430828377
# (225, 225, 1)
# (225, 225, 2)
# 24500 total loss:2.070951780354854 d_loss:0.6665540937840504
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 24600 total loss:2.070774367347834 d_loss:0.666557335369101
# (225, 225, 1)
# (225, 225, 2)
# 24700 total loss:2.0705754092278004 d_loss:0.6665515325436293
# (225, 225, 1)
# (225, 225, 2)
# 24800 total loss:2.0703474393722687 d_loss:0.6665564181185452
# (225, 225, 1)
# (225, 225, 2)
# 24900 total loss:2.070117888769058 d_loss:0.6665438136946811
# (225, 225, 1)
# (225, 225, 2)
# 25000 total loss:2.0699375106412643 d_loss:0.666542499761457
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 25100 total loss:2.069698830647429 d_loss:0.6665275798821394
# (225, 225, 1)
# (225, 225, 2)
# 25200 total loss:2.0695770725050084 d_loss:0.6665041535685698
# (225, 225, 1)
# (225, 225, 2)
# 25300 total loss:2.069519053065781 d_loss:0.666502044069394
# (225, 225, 1)
# (225, 225, 2)
# 25400 total loss:2.0693711144150266 d_loss:0.6664984980816291
# (225, 225, 1)
# (225, 225, 2)
# 25500 total loss:2.0691301617209508 d_loss:0.6664856749067365
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 25600 total loss:2.0689903549289 d_loss:0.6664702513536319
# (225, 225, 1)
# (225, 225, 2)
# 25700 total loss:2.068765315145478 d_loss:0.6664696496462307
# (225, 225, 1)
# (225, 225, 2)
# 25800 total loss:2.0685750925190973 d_loss:0.666470503185262
# (225, 225, 1)
# (225, 225, 2)
# 25900 total loss:2.0684431387712343 d_loss:0.6664506822770153
# (225, 225, 1)
# (225, 225, 2)
# 26000 total loss:2.0683646586018063 d_loss:0.6664351130342206
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 26100 total loss:2.0681456252352897 d_loss:0.6664243003651893
# (225, 225, 1)
# (225, 225, 2)
# 26200 total loss:2.0679310847637074 d_loss:0.6664258387797304
# (225, 225, 1)
# (225, 225, 2)
# 26300 total loss:2.0677058346882933 d_loss:0.6664209852962494
# (225, 225, 1)
# (225, 225, 2)
# 26400 total loss:2.0674965409165673 d_loss:0.6664241348885024
# (225, 225, 1)
# (225, 225, 2)
# 26500 total loss:2.06740675989237 d_loss:0.6664134281281268
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 26600 total loss:2.0672403485527187 d_loss:0.6664024077043327
# (225, 225, 1)
# (225, 225, 2)
# 26700 total loss:2.0671256691867965 d_loss:0.6663965052468483
# (225, 225, 1)
# (225, 225, 2)
# 26800 total loss:2.066957211597619 d_loss:0.6663926266048208
# (225, 225, 1)
# (225, 225, 2)
# 26900 total loss:2.066835112422979 d_loss:0.6663579513490563
# (225, 225, 1)
# (225, 225, 2)
# 27000 total loss:2.0666550473413294 d_loss:0.6663688046845404
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 27100 total loss:2.0664982525106836 d_loss:0.6663627205643752
# (225, 225, 1)
# (225, 225, 2)
# 27200 total loss:2.066335935561252 d_loss:0.6663486720366008
# (225, 225, 1)
# (225, 225, 2)
# 27300 total loss:2.066248590180036 d_loss:0.6663352927179228
# (225, 225, 1)
# (225, 225, 2)
# 27400 total loss:2.0661010448525494 d_loss:0.6663219040782973
# (225, 225, 1)
# (225, 225, 2)
# 27500 total loss:2.065984384475449 d_loss:0.6663140644170077
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 27600 total loss:2.0658689148939584 d_loss:0.6662915449827473
# (225, 225, 1)
# (225, 225, 2)
# 27700 total loss:2.065767572397842 d_loss:0.6662936657859505
# (225, 225, 1)
# (225, 225, 2)
# 27800 total loss:2.065584881374886 d_loss:0.666288767030613
# (225, 225, 1)
# (225, 225, 2)
# 27900 total loss:2.0654584865647503 d_loss:0.6662888158271552
# (225, 225, 1)
# (225, 225, 2)
# 28000 total loss:2.065335231731402 d_loss:0.6662840035164882
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 28100 total loss:2.0652148090415494 d_loss:0.6662777975263423
# (225, 225, 1)
# (225, 225, 2)
# 28200 total loss:2.0649639320501905 d_loss:0.6662797462807473
# (225, 225, 1)
# (225, 225, 2)
# 28300 total loss:2.064778362073284 d_loss:0.6662765317284405
# (225, 225, 1)
# (225, 225, 2)
# 28400 total loss:2.064623979140202 d_loss:0.6662643421906348
# (225, 225, 1)
# (225, 225, 2)
# 28500 total loss:2.0645262188821105 d_loss:0.6662487744152367
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 28600 total loss:2.064490153249248 d_loss:0.6662359137194516
# (225, 225, 1)
# (225, 225, 2)
# 28700 total loss:2.0643919840252947 d_loss:0.6662219565172667
# (225, 225, 1)
# (225, 225, 2)
# 28800 total loss:2.0642218963747325 d_loss:0.6662122839353983
# (225, 225, 1)
# (225, 225, 2)
# 28900 total loss:2.0641008949433064 d_loss:0.666213063577509
# (225, 225, 1)
# (225, 225, 2)
# 29000 total loss:2.0639684554284994 d_loss:0.6662028107206057
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 29100 total loss:2.0639155524804473 d_loss:0.6661771865406956
# (225, 225, 1)
# (225, 225, 2)
# 29200 total loss:2.0638572939380793 d_loss:0.6661614348732373
# (225, 225, 1)
# (225, 225, 2)
# 29300 total loss:2.0637359308393224 d_loss:0.6661494765749224
# (225, 225, 1)
# (225, 225, 2)
# 29400 total loss:2.0637166726865193 d_loss:0.6661349043448053
# (225, 225, 1)
# (225, 225, 2)
# 29500 total loss:2.0636169976013856 d_loss:0.6661239633304074
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 29600 total loss:2.0634269659182625 d_loss:0.6661177553115221
# (225, 225, 1)
# (225, 225, 2)
# 29700 total loss:2.0632856383050115 d_loss:0.6661164571937026
# (225, 225, 1)
# (225, 225, 2)
# 29800 total loss:2.063086080705541 d_loss:0.6661088408835536
# (225, 225, 1)
# (225, 225, 2)
# 29900 total loss:2.0629860743970374 d_loss:0.6660954429205612
# (225, 225, 1)
# (225, 225, 2)
# 30000 total loss:2.062939231628005 d_loss:0.6660716389734195
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 30100 total loss:2.0627423699387344 d_loss:0.6660778822122381
# (225, 225, 1)
# (225, 225, 2)
# 30200 total loss:2.0626959282650557 d_loss:0.6660620851019747
# (225, 225, 1)
# (225, 225, 2)
# 30300 total loss:2.062506221614682 d_loss:0.6660547596375942
# (225, 225, 1)
# (225, 225, 2)
# 30400 total loss:2.062395333577156 d_loss:0.6660485889814538
# (225, 225, 1)
# (225, 225, 2)
# ...
# 52100 total loss:2.0502604215365134 d_loss:0.6630242724210529
# (225, 225, 1)
# (225, 225, 2)
# 52200 total loss:2.0501896254607455 d_loss:0.6630123806588035
# (225, 225, 1)
# (225, 225, 2)
# 52300 total loss:2.0501871036663846 d_loss:0.6629955931975627
# (225, 225, 1)
# (225, 225, 2)
# 52400 total loss:2.0501333293344777 d_loss:0.6629918893760014
# (225, 225, 1)
# (225, 225, 2)
# 52500 total loss:2.050054751935005 d_loss:0.6629847496686556
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 52600 total loss:2.0500287946459115 d_loss:0.6629708073024794
# (225, 225, 1)
# (225, 225, 2)
# 52700 total loss:2.050006567781512 d_loss:0.6629553057551131
# (225, 225, 1)
# (225, 225, 2)
# 52800 total loss:2.049945832199634 d_loss:0.6629484332306361
# (225, 225, 1)
# (225, 225, 2)
# 52900 total loss:2.0498485914649 d_loss:0.6629411154936423
# (225, 225, 1)
# (225, 225, 2)
# 53000 total loss:2.0497765573194906 d_loss:0.662930295865686
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 53100 total loss:2.0496891612097294 d_loss:0.6629168031349736
# (225, 225, 1)
# (225, 225, 2)
# 53200 total loss:2.0496879199517166 d_loss:0.6629024924865974
# (225, 225, 1)
# (225, 225, 2)
# 53300 total loss:2.049606058678555 d_loss:0.6628966088353667
# (225, 225, 1)
# (225, 225, 2)
# 53400 total loss:2.0495517550843996 d_loss:0.662888512677444
# (225, 225, 1)
# (225, 225, 2)
# 53500 total loss:2.049503688346462 d_loss:0.6628732514979895
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 53600 total loss:2.0494599945631635 d_loss:0.6628644594911257
# (225, 225, 1)
# (225, 225, 2)
# 53700 total loss:2.0494358246269586 d_loss:0.6628473102521308
# (225, 225, 1)
# (225, 225, 2)
# 53800 total loss:2.0493689421457204 d_loss:0.662831618463966
# (225, 225, 1)
# (225, 225, 2)
# 53900 total loss:2.0492997082665716 d_loss:0.6628232717085427
# (225, 225, 1)
# (225, 225, 2)
# 54000 total loss:2.0492610677352787 d_loss:0.662813686832839
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 54100 total loss:2.0492096287214983 d_loss:0.6628057156531104
# (225, 225, 1)
# (225, 225, 2)
# 54200 total loss:2.0491962280003366 d_loss:0.6627934965247001
# (225, 225, 1)
# (225, 225, 2)
# 54300 total loss:2.0491886442268297 d_loss:0.6627805049080755
# (225, 225, 1)
# (225, 225, 2)
# 54400 total loss:2.0491572492900554 d_loss:0.6627617000396667
# (225, 225, 1)
# (225, 225, 2)
# 54500 total loss:2.0491199696541327 d_loss:0.6627519930760777
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 54600 total loss:2.0490792289509003 d_loss:0.6627419543086397
# (225, 225, 1)
# (225, 225, 2)
# 54700 total loss:2.049050275761765 d_loss:0.6627228307684339
# (225, 225, 1)
# (225, 225, 2)
# 54800 total loss:2.0490908104364602 d_loss:0.6627091045755407
# (225, 225, 1)
# (225, 225, 2)
# 54900 total loss:2.049077326095258 d_loss:0.6626937755601168
# (225, 225, 1)
# (225, 225, 2)
# 55000 total loss:2.0490367612141314 d_loss:0.6626827207733755
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 55100 total loss:2.048976671403403 d_loss:0.6626694394919775
# (225, 225, 1)
# (225, 225, 2)
# 55200 total loss:2.0489277811521496 d_loss:0.6626644302428503
# (225, 225, 1)
# (225, 225, 2)
# 55300 total loss:2.0488811955525303 d_loss:0.6626504100060258
# (225, 225, 1)
# (225, 225, 2)
# 55400 total loss:2.0488643702379266 d_loss:0.6626306525460264
# (225, 225, 1)
# (225, 225, 2)
# 55500 total loss:2.0487886113185168 d_loss:0.6626268696651492
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 55600 total loss:2.048766860329235 d_loss:0.6626083071261841
# (225, 225, 1)
# (225, 225, 2)
# 55700 total loss:2.048733264023225 d_loss:0.6625972514648863
# (225, 225, 1)
# (225, 225, 2)
# 55800 total loss:2.048724513923695 d_loss:0.6625861596121924
# (225, 225, 1)
# (225, 225, 2)
# 55900 total loss:2.048674378818826 d_loss:0.662577234679138
# (225, 225, 1)
# (225, 225, 2)
# 56000 total loss:2.048619854260957 d_loss:0.6625641895725991
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 56100 total loss:2.0486388599270327 d_loss:0.6625568243388259
# (225, 225, 1)
# (225, 225, 2)
# 56200 total loss:2.0486579259428708 d_loss:0.6625266289908065
# (225, 225, 1)
# (225, 225, 2)
# 56300 total loss:2.048666909321932 d_loss:0.662511907999415
# (225, 225, 1)
# (225, 225, 2)
# 56400 total loss:2.048634000592666 d_loss:0.6625021942200593
# (225, 225, 1)
# (225, 225, 2)
# 56500 total loss:2.0486212551389924 d_loss:0.6624868940315136
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 56600 total loss:2.048574890181106 d_loss:0.6624754341633687
# (225, 225, 1)
# (225, 225, 2)
# 56700 total loss:2.0485469659390705 d_loss:0.6624629781340957
# (225, 225, 1)
# (225, 225, 2)
# 56800 total loss:2.0485068261271593 d_loss:0.662452085167662
# (225, 225, 1)
# (225, 225, 2)
# 56900 total loss:2.048478472924361 d_loss:0.6624332310024058
# (225, 225, 1)
# (225, 225, 2)
# 57000 total loss:2.048421233547865 d_loss:0.6624219868328853
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 57100 total loss:2.048398185643926 d_loss:0.6624130239647518
# (225, 225, 1)
# (225, 225, 2)
# 57200 total loss:2.048375235491908 d_loss:0.6624026126336177
# (225, 225, 1)
# (225, 225, 2)
# 57300 total loss:2.04836392636692 d_loss:0.6623925236743826
# (225, 225, 1)
# (225, 225, 2)
# 57400 total loss:2.048314640796986 d_loss:0.6623799471429866
# (225, 225, 1)
# (225, 225, 2)
# 57500 total loss:2.04828104654647 d_loss:0.6623712365081867
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 57600 total loss:2.0482822131208844 d_loss:0.6623544298736919
# (225, 225, 1)
# (225, 225, 2)
# 57700 total loss:2.048256950201464 d_loss:0.6623372556777792
# (225, 225, 1)
# (225, 225, 2)
# 57800 total loss:2.0482385972138237 d_loss:0.6623224823819744
# (225, 225, 1)
# (225, 225, 2)
# 57900 total loss:2.0481947706872905 d_loss:0.6623116994359641
# (225, 225, 1)
# (225, 225, 2)
# 58000 total loss:2.0481934494931786 d_loss:0.6622970624988108
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 58100 total loss:2.048220476756021 d_loss:0.6622778713285532
# (225, 225, 1)
# (225, 225, 2)
# 58200 total loss:2.048205595299442 d_loss:0.6622581363399103
# (225, 225, 1)
# (225, 225, 2)
# 58300 total loss:2.0481877896215495 d_loss:0.662240737630911
# (225, 225, 1)
# (225, 225, 2)
# 58400 total loss:2.0481429872495265 d_loss:0.6622210466110564
# (225, 225, 1)
# (225, 225, 2)
# 58500 total loss:2.0481219409263844 d_loss:0.6622052196492847
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 58600 total loss:2.0480918040855247 d_loss:0.6621939050396167
# (225, 225, 1)
# (225, 225, 2)
# 58700 total loss:2.0480549622287683 d_loss:0.6621799570340016
# (225, 225, 1)
# (225, 225, 2)
# 58800 total loss:2.0479906286885465 d_loss:0.6621656610929401
# (225, 225, 1)
# (225, 225, 2)
# 58900 total loss:2.047952681016324 d_loss:0.6621522299476852
# (225, 225, 1)
# (225, 225, 2)
# 59000 total loss:2.0479298354839606 d_loss:0.6621386925634429
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 59100 total loss:2.047889372469034 d_loss:0.6621239291832554
# (225, 225, 1)
# (225, 225, 2)
# 59200 total loss:2.0478814098714353 d_loss:0.6621039752667549
# (225, 225, 1)
# (225, 225, 2)
# 59300 total loss:2.047842448522508 d_loss:0.6620948415313886
# (225, 225, 1)
# (225, 225, 2)
# 59400 total loss:2.0478222461198503 d_loss:0.6620740337793959
# (225, 225, 1)
# (225, 225, 2)
# 59500 total loss:2.0477821103576703 d_loss:0.6620640173919218
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 59600 total loss:2.047716843726028 d_loss:0.6620544476741801
# (225, 225, 1)
# (225, 225, 2)
# 59700 total loss:2.0476786172684607 d_loss:0.6620390498681097
# (225, 225, 1)
# (225, 225, 2)
# 59800 total loss:2.047669157182717 d_loss:0.6620269348689717
# (225, 225, 1)
# (225, 225, 2)
# 59900 total loss:2.0476296489496093 d_loss:0.6620153778039671
# (225, 225, 1)
# (225, 225, 2)
# 60000 total loss:2.0475913873582963 d_loss:0.6620013431409143
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 60100 total loss:2.047548305999988 d_loss:0.6619854356611795
# (225, 225, 1)
# (225, 225, 2)
# 60200 total loss:2.0475207645531124 d_loss:0.6619752576170526
# (225, 225, 1)
# (225, 225, 2)
# 60300 total loss:2.047493155841841 d_loss:0.6619574923819338
# (225, 225, 1)
# (225, 225, 2)
# 60400 total loss:2.0474622462873566 d_loss:0.6619434744196508
# (225, 225, 1)
# (225, 225, 2)
# 60500 total loss:2.0473958891156325 d_loss:0.6619351233878373
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 60600 total loss:2.047364863129175 d_loss:0.6619170066759473
# (225, 225, 1)
# (225, 225, 2)
# 60700 total loss:2.0473448070229976 d_loss:0.6619022856248394
# (225, 225, 1)
# (225, 225, 2)
# 60800 total loss:2.0473168229992234 d_loss:0.6618841913260565
# (225, 225, 1)
# (225, 225, 2)
# 60900 total loss:2.0472674244105793 d_loss:0.6618755435343937
# (225, 225, 1)
# (225, 225, 2)
# 61000 total loss:2.0472779296635992 d_loss:0.661859894321864
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 61100 total loss:2.047256926745234 d_loss:0.6618457706282228
# (225, 225, 1)
# (225, 225, 2)
# 61200 total loss:2.047229930122728 d_loss:0.661834998100577
# (225, 225, 1)
# (225, 225, 2)
# 61300 total loss:2.047219511441684 d_loss:0.6618182637297957
# (225, 225, 1)
# (225, 225, 2)
# 61400 total loss:2.0471934481817446 d_loss:0.6618083423921443
# (225, 225, 1)
# (225, 225, 2)
# 61500 total loss:2.0471785119509147 d_loss:0.6617958043002333
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 61600 total loss:2.0471419183521147 d_loss:0.6617779784145023
# (225, 225, 1)
# (225, 225, 2)
# 61700 total loss:2.0470829030991524 d_loss:0.6617647257089276
# (225, 225, 1)
# (225, 225, 2)
# 61800 total loss:2.047069147193243 d_loss:0.6617538913905667
# (225, 225, 1)
# (225, 225, 2)
# 61900 total loss:2.04702764362919 d_loss:0.661742062915713
# (225, 225, 1)
# (225, 225, 2)
# 62000 total loss:2.0470110772876744 d_loss:0.6617326674134919
# (225, 225, 1)
# (225, 225, 2)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 62100 total loss:2.046967281759402 d_loss:0.6617144649327579
# (225, 225, 1)
# (225, 225, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fd85701bf924> in <module>
#      94 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#      95
# ---> 96 train_gan()
#
# <ipython-input-1-fd85701bf924> in train_gan()
#      77
#      78         loss_discriminator_fake = terrain_discriminator.train_on_batch(
# ---> 79             [Y_fake, X_real], labels_fake)
#      80         loss_discriminator_real = terrain_discriminator.train_on_batch(
#      81             [Y_target, X_real], labels_real)
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1854                                                     class_weight)
#    1855       self.train_function = self.make_train_function()
# -> 1856       logs = self.train_function(iterator)
#    1857
#    1858     if reset_metrics:
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# ~/.conda/envs/zc_terrain/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
